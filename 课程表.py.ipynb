# %%
print("_"*110)
print("{:^16}｜{:^14}|{:^15}|{:^15}|{:^15}|{:^12}|".format("时 间","星期一","星期二","星期三","星期四","星期五"))
print("_"*110)
print("{:^15}｜{:^17}|{:^18}|{:^16}|{:^18}|{:^15}|"
      .format("第一节","","","击剑","","",""))
print("{:^18}｜{:^17}|{:^18}|{:^15}|{:^18}|{:^15}|"
      .format("","","","刘禹彤","","",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^18}|{:^16}|{:^18}|{:^15}|"
      .format("第二节","","","击剑","","",""))
print("{:^18}｜{:^17}|{:^18}|{:^15}|{:^18}|{:^15}|"
      .format("","","","刘禹彤","","",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^18}|{:^14}|{:^16}|{:^15}|"
      .format("第三节","","","毛概理论","Python语言","",""))
print("{:^18}｜{:^17}|{:^18}|{:^16}|{:^15}|{:^15}|"
      .format("","","","周伟","许智超","",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^14}|{:^14}|{:^16}|{:^11}|"
      .format("第四节","","毛概实践","毛概理论","Python语言","AI软件应用",""))
print("{:^18}｜{:^17}|{:^15}|{:^16}|{:^15}|{:^12}|"
      .format("","","杨益孜","周伟","许智超","阚凤霞",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^14}|{:^14}|{:^16}|{:^11}|"
      .format("第五节","","毛概实践","毛概理论","Python语言","AI软件应用",""))
print("{:^18}｜{:^17}|{:^15}|{:^16}|{:^15}|{:^12}|"
      .format("","","杨益孜","周伟","许智超","阚凤霞",""))
print("_"*110)
print("{:^15}｜{:^13}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("第六节","写作训练","","","","",""))
print("{:^18}｜{:^17}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("","","","","","",""))
print("_"*110)
print("{:^15}｜{:^13}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("第七节","写作训练","","","","",""))
print("{:^18}｜{:^17}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("","","","","","",""))
print("_"*110)
print("{:^15}｜{:^9}|{:^11}|{:^18}|{:^14}|{:^15}|"
      .format("第八节","创业基础（实践）","网站运营与管理","","大学英语","",""))
print("{:^18}｜{:^15}|{:^15}|{:^18}|{:^15}|{:^15}|"
      .format("","高进","胡美香","","黄梓萱","","",""))
print("_"*110)
print("{:^15}｜{:^9}|{:^11}|{:^18}|{:^14}|{:^15}|"
      .format("第九节","创业基础（实践）","网站运营与管理","","大学英语","",""))
print("{:^18}｜{:^15}|{:^15}|{:^18}|{:^15}|{:^15}|"
      .format("","高进","胡美香","","黄梓萱","","",""))
print("_"*110)
print("{:^15}｜{:^9}|{:^11}|{:^18}|{:^18}|{:^15}|"
      .format("第十节","创业基础（实践）","网站运营与管理","","","",""))
print("{:^18}｜{:^15}|{:^15}|{:^18}|{:^18}|{:^15}|"
      .format("","高进","胡美香","","","","",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("十一节","","","","","",""))
print("{:^18}｜{:^17}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("","","","","","","",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^14}|{:^18}|{:^18}|{:^15}|"
      .format("十二节","","大学英语","","","",""))
print("{:^18}｜{:^17}|{:^15}|{:^18}|{:^18}|{:^15}|"
      .format("","","黄梓萱","","","","","",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^14}|{:^18}|{:^18}|{:^15}|"
      .format("十三节","","大学英语","","","",""))
print("{:^18}｜{:^17}|{:^15}|{:^18}|{:^18}|{:^15}|"
      .format("","","黄梓萱","","","","","",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("十四节","","","","","",""))
print("{:^18}｜{:^17}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("","","","","","","","",""))
print("_"*110)
print("{:^15}｜{:^17}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("十五节","","","","","",""))
print("{:^18}｜{:^17}|{:^18}|{:^18}|{:^18}|{:^15}|"
      .format("","","","","","","","",""))
print("_"*110)
# Out:
# ______________________________________________________________________________________________________________
#       时 间       ｜     星期一      |      星期二      |      星期三      |      星期四      |    星期五     |
# ______________________________________________________________________________________________________________
#       第一节      ｜                 |                  |       击剑       |                  |               |
#                   ｜                 |                  |      刘禹彤      |                  |               |
# ______________________________________________________________________________________________________________
#       第二节      ｜                 |                  |       击剑       |                  |               |
#                   ｜                 |                  |      刘禹彤      |                  |               |
# ______________________________________________________________________________________________________________
# ...
